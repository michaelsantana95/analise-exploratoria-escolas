# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('situacaofinalalunos2022.csv', sep = ';')
df
# Out:
#         ano      nescolnome  ebairrnome     eescolruae aescolnume  cescolrpae  \
# 0      2022    ABILIO GOMES  BOA VIAGEM   BRUNO VELOZO        S/N           6
# 1      2022    ABILIO GOMES  BOA VIAGEM   BRUNO VELOZO        S/N           6
# 2      2022    ABILIO GOMES  BOA VIAGEM   BRUNO VELOZO        S/N           6
# 3      2022    ABILIO GOMES  BOA VIAGEM   BRUNO VELOZO        S/N           6
# 4      2022    ABILIO GOMES  BOA VIAGEM   BRUNO VELOZO        S/N           6
# ...     ...             ...         ...            ...        ...         ...
# 97255  2022  27 DE NOVEMBRO       COHAB  DOZE DE JUNHO       1120           6
# 97256  2022  27 DE NOVEMBRO       COHAB  DOZE DE JUNHO       1120           6
# 97257  2022  27 DE NOVEMBRO       COHAB  DOZE DE JUNHO       1120           6
# 97258  2022  27 DE NOVEMBRO       COHAB  DOZE DE JUNHO       1120           6
# 97259  2022  27 DE NOVEMBRO       COHAB  DOZE DE JUNHO       1120           6
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97260 entries, 0 to 97259
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ano         97260 non-null  int64
#  1   nescolnome  97260 non-null  object
#  2   ebairrnome  97260 non-null  object
#  3   eescolruae  94937 non-null  object
#  4   aescolnume  97260 non-null  object
#  5   cescolrpae  97260 non-null  int64
#  6   modens      97260 non-null  int64
#  7   compens     97169 non-null  object
#  8   anoensino   97260 non-null  object
#  9   esermodesc  97169 non-null  object
#  10  nmodennome  97260 non-null  object
#  11  turma       97260 non-null  object
#  12  nturesnome  97260 non-null  object
#  13  mat         97260 non-null  int64
#  14  alunosexo   97260 non-null  object
#  15  situ        97260 non-null  object
#  16  esitaldesc  97260 non-null  object
# dtypes: int64(4), object(13)
# memory usage: 12.6+ MB

# %%
df['anoensino'].unique()
# Out:
# array(['GRUPO V', '1º ANO', '2º ANO', '3º ANO', '4º ANO', '5º ANO',
#        'MÓDULO 1', 'MÓDULO 2', 'MÓDULO 3', 'BERÇÁRIO', 'GRUPO I',
#        'GRUPO II', 'GRUPO III', 'GRUPO IV',
#        'CORRECAO DE FLUXO 1 - ALFABETIZACAO',
#        'CORRECAO DE FLUXO 2 - ACELERACAO', '6º ANO', '7º ANO', '8º ANO',
#        '9º ANO', 'MÓDULO 4', 'MÓDULO 5', 'TRAVESSIA RECIFE'], dtype=object)

# %%
df[df['anoensino']=='9º ANO']
# Out:
#         ano     nescolnome ebairrnome      eescolruae aescolnume  cescolrpae  \
# 4615   2022  ANDRE DE MELO   ESTANCIA  MORAES E SILVA        180           5
# 4616   2022  ANDRE DE MELO   ESTANCIA  MORAES E SILVA        180           5
# 4617   2022  ANDRE DE MELO   ESTANCIA  MORAES E SILVA        180           5
# 4618   2022  ANDRE DE MELO   ESTANCIA  MORAES E SILVA        180           5
# 4619   2022  ANDRE DE MELO   ESTANCIA  MORAES E SILVA        180           5
# ...     ...            ...        ...             ...        ...         ...
# 94994  2022    VILA SESAMO      COHAB  VALE DO CARIRI        290           6
# 94995  2022    VILA SESAMO      COHAB  VALE DO CARIRI        290           6
# 94996  2022    VILA SESAMO      COHAB  VALE DO CARIRI        290           6
# 94997  2022    VILA SESAMO      COHAB  VALE DO CARIRI        290           6
# 94998  2022    VILA SESAMO      COHAB  VALE DO CARIRI        290           6
#
# ...

# %%
df.loc[(df['anoensino']=='9º ANO'), ['ano', 'nescolnome', 'ebairrnome', 'cescolrpae', 'anoensino', 'nturesnome', 'mat', 'alunosexo', 'situ', 'esitaldesc']]
# Out:
#         ano     nescolnome ebairrnome  cescolrpae anoensino nturesnome  \
# 4615   2022  ANDRE DE MELO   ESTANCIA           5    9º ANO      TARDE
# 4616   2022  ANDRE DE MELO   ESTANCIA           5    9º ANO      TARDE
# 4617   2022  ANDRE DE MELO   ESTANCIA           5    9º ANO      TARDE
# 4618   2022  ANDRE DE MELO   ESTANCIA           5    9º ANO      TARDE
# 4619   2022  ANDRE DE MELO   ESTANCIA           5    9º ANO      TARDE
# ...     ...            ...        ...         ...       ...        ...
# 94994  2022    VILA SESAMO      COHAB           6    9º ANO      TARDE
# 94995  2022    VILA SESAMO      COHAB           6    9º ANO      TARDE
# 94996  2022    VILA SESAMO      COHAB           6    9º ANO      TARDE
# 94997  2022    VILA SESAMO      COHAB           6    9º ANO      TARDE
# 94998  2022    VILA SESAMO      COHAB           6    9º ANO      TARDE
#
#             mat alunosexo situ         esitaldesc
# 4615   18046398         F   AP           APROVADO
# ...
