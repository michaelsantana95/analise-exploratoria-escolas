# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('situacaofinalalunos2019.csv', sep = ';')
df
# Out:
#         ano      nescolnome  ebairrnome     eescolruae aescolnume  cescolrpae  \
# 0      2019    ABILIO GOMES  BOA VIAGEM   BRUNO VELOZO        S/N           6
# 1      2019    ABILIO GOMES  BOA VIAGEM   BRUNO VELOZO        S/N           6
# 2      2019    ABILIO GOMES  BOA VIAGEM   BRUNO VELOZO        S/N           6
# 3      2019    ABILIO GOMES  BOA VIAGEM   BRUNO VELOZO        S/N           6
# 4      2019    ABILIO GOMES  BOA VIAGEM   BRUNO VELOZO        S/N           6
# ...     ...             ...         ...            ...        ...         ...
# 97362  2019  27 DE NOVEMBRO       COHAB  DOZE DE JUNHO       1120           6
# 97363  2019  27 DE NOVEMBRO       COHAB  DOZE DE JUNHO       1120           6
# 97364  2019  27 DE NOVEMBRO       COHAB  DOZE DE JUNHO       1120           6
# 97365  2019  27 DE NOVEMBRO       COHAB  DOZE DE JUNHO       1120           6
# 97366  2019  27 DE NOVEMBRO       COHAB  DOZE DE JUNHO       1120           6
#
#        modens compens anoensino esermodesc          nmodennome turma  \
# 0           0       5   GRUPO V    GRUPO V   EDUCACAO INFANTIL     A
# 1           0       5   GRUPO V    GRUPO V   EDUCACAO INFANTIL     A
# 2           0       5   GRUPO V    GRUPO V   EDUCACAO INFANTIL     A
# 3           0       5   GRUPO V    GRUPO V   EDUCACAO INFANTIL     A
# 4           0       5   GRUPO V    GRUPO V   EDUCACAO INFANTIL     A
# ...       ...     ...       ...        ...                 ...   ...
# 97362       1       4    5º ANO     5º ANO  ENSINO FUNDAMENTAL     B
# 97363       1       4    5º ANO     5º ANO  ENSINO FUNDAMENTAL     B
# 97364       1       4    5º ANO     5º ANO  ENSINO FUNDAMENTAL     B
# 97365       1       4    5º ANO     5º ANO  ENSINO FUNDAMENTAL     B
# 97366       1       4    5º ANO     5º ANO  ENSINO FUNDAMENTAL     B
#
#       nturesnome       mat alunosexo situ esitaldesc
# 0          MANHÃ  17049660         F   AP   APROVADO
# 1          MANHÃ  18630162         F   AP   APROVADO
# 2          MANHÃ  19006314         F   AP   APROVADO
# 3          MANHÃ  19000596         M   AP   APROVADO
# 4          MANHÃ  19013272         M   AP   APROVADO
# ...          ...       ...       ...  ...        ...
# 97362      TARDE  13232231         M   AP   APROVADO
# 97363      TARDE  11695722         M   AP   APROVADO
# 97364      TARDE  14156032         M   AP   APROVADO
# 97365      TARDE  13232274         F   AP   APROVADO
# 97366      TARDE  13149512         F   AP   APROVADO
#
# [97367 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97367 entries, 0 to 97366
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ano         97367 non-null  int64
#  1   nescolnome  97367 non-null  object
#  2   ebairrnome  97367 non-null  object
#  3   eescolruae  97367 non-null  object
#  4   aescolnume  97367 non-null  object
#  5   cescolrpae  97367 non-null  int64
#  6   modens      97367 non-null  int64
#  7   compens     97367 non-null  object
#  8   anoensino   97367 non-null  object
#  9   esermodesc  97367 non-null  object
#  10  nmodennome  97367 non-null  object
#  11  turma       97367 non-null  object
#  12  nturesnome  97367 non-null  object
#  13  mat         97367 non-null  int64
#  14  alunosexo   97367 non-null  object
#  15  situ        97367 non-null  object
#  16  esitaldesc  97367 non-null  object
# dtypes: int64(4), object(13)
# memory usage: 12.6+ MB

# %%
df['anoensino'].unique()
# Out:
# array(['GRUPO V', '1º ANO', '2º ANO', '3º ANO', '4º ANO', '5º ANO',
#        'MÓDULO 2', 'MÓDULO 1', 'MÓDULO 3', 'BERÇÁRIO', 'GRUPO I',
#        'GRUPO II', 'GRUPO III', 'GRUPO IV', 'ACELERA', 'SE LIGA',
#        'PROJOVEM', 'MÓDULO 4', 'MÓDULO 5', '6º ANO', '7º ANO', '8º ANO',
#        '9º ANO', 'TRAVESSIA RECIFE'], dtype=object)

# %%
df[df['anoensino']=='9º ANO']
# Out:
#         ano     nescolnome ebairrnome      eescolruae aescolnume  cescolrpae  \
# 4818   2019  ANDRE DE MELO   ESTANCIA  MORAES E SILVA        180           5
# 4819   2019  ANDRE DE MELO   ESTANCIA  MORAES E SILVA        180           5
# 4820   2019  ANDRE DE MELO   ESTANCIA  MORAES E SILVA        180           5
# 4821   2019  ANDRE DE MELO   ESTANCIA  MORAES E SILVA        180           5
# 4822   2019  ANDRE DE MELO   ESTANCIA  MORAES E SILVA        180           5
# ...     ...            ...        ...             ...        ...         ...
# 95082  2019    VILA SESAMO      COHAB  VALE DO CARIRI        290           6
# 95083  2019    VILA SESAMO      COHAB  VALE DO CARIRI        290           6
# 95084  2019    VILA SESAMO      COHAB  VALE DO CARIRI        290           6
# 95085  2019    VILA SESAMO      COHAB  VALE DO CARIRI        290           6
# 95086  2019    VILA SESAMO      COHAB  VALE DO CARIRI        290           6
#
#        modens compens anoensino esermodesc          nmodennome turma  \
# 4818        1       8    9º ANO     9º ANO  ENSINO FUNDAMENTAL     A
# 4819        1       8    9º ANO     9º ANO  ENSINO FUNDAMENTAL     A
# 4820        1       8    9º ANO     9º ANO  ENSINO FUNDAMENTAL     A
# 4821        1       8    9º ANO     9º ANO  ENSINO FUNDAMENTAL     A
# 4822        1       8    9º ANO     9º ANO  ENSINO FUNDAMENTAL     A
# ...       ...     ...       ...        ...                 ...   ...
# 95082       1       8    9º ANO     9º ANO  ENSINO FUNDAMENTAL     B
# 95083       1       8    9º ANO     9º ANO  ENSINO FUNDAMENTAL     B
# 95084       1       8    9º ANO     9º ANO  ENSINO FUNDAMENTAL     B
# 95085       1       8    9º ANO     9º ANO  ENSINO FUNDAMENTAL     B
# 95086       1       8    9º ANO     9º ANO  ENSINO FUNDAMENTAL     B
#
#       nturesnome       mat alunosexo situ            esitaldesc
# 4818       TARDE  15755274         M   TA     TR DUR ANO P/REDE
# 4819       TARDE  14286068         F   RN  RENV S/SIT FINAL DEF
# 4820       TARDE   5035864         M   RN  RENV S/SIT FINAL DEF
# 4821       TARDE  12059293         M   RN  RENV S/SIT FINAL DEF
# 4822       TARDE  13165470         M   RN  RENV S/SIT FINAL DEF
# ...          ...       ...       ...  ...                   ...
# 95082      TARDE  10151230         F   RN  RENV S/SIT FINAL DEF
# 95083      TARDE   5093252         F   RN  RENV S/SIT FINAL DEF
# 95084      TARDE   6280501         M   RN  RENV S/SIT FINAL DEF
# 95085      TARDE  15076784         F   RN  RENV S/SIT FINAL DEF
# 95086      TARDE   9115560         F   RN  RENV S/SIT FINAL DEF
#
# [2420 rows x 17 columns]

# %%
da = df.loc[(df['anoensino']=='9º ANO'), ['ano', 'nescolnome', 'ebairrnome', 'cescolrpae', 'anoensino', 'nturesnome', 'mat', 'alunosexo', 'situ', 'esitaldesc']]

# %%
da.to_csv('tabela9ano2019.csv', sep = ';' , index=False)
da
# Out:
#         ano     nescolnome ebairrnome  cescolrpae anoensino nturesnome  \
# 4818   2019  ANDRE DE MELO   ESTANCIA           5    9º ANO      TARDE
# 4819   2019  ANDRE DE MELO   ESTANCIA           5    9º ANO      TARDE
# 4820   2019  ANDRE DE MELO   ESTANCIA           5    9º ANO      TARDE
# 4821   2019  ANDRE DE MELO   ESTANCIA           5    9º ANO      TARDE
# 4822   2019  ANDRE DE MELO   ESTANCIA           5    9º ANO      TARDE
# ...     ...            ...        ...         ...       ...        ...
# 95082  2019    VILA SESAMO      COHAB           6    9º ANO      TARDE
# 95083  2019    VILA SESAMO      COHAB           6    9º ANO      TARDE
# 95084  2019    VILA SESAMO      COHAB           6    9º ANO      TARDE
# 95085  2019    VILA SESAMO      COHAB           6    9º ANO      TARDE
# 95086  2019    VILA SESAMO      COHAB           6    9º ANO      TARDE
#
#             mat alunosexo situ            esitaldesc
# 4818   15755274         M   TA     TR DUR ANO P/REDE
# 4819   14286068         F   RN  RENV S/SIT FINAL DEF
# 4820    5035864         M   RN  RENV S/SIT FINAL DEF
# 4821   12059293         M   RN  RENV S/SIT FINAL DEF
# 4822   13165470         M   RN  RENV S/SIT FINAL DEF
# ...         ...       ...  ...                   ...
# 95082  10151230         F   RN  RENV S/SIT FINAL DEF
# 95083   5093252         F   RN  RENV S/SIT FINAL DEF
# 95084   6280501         M   RN  RENV S/SIT FINAL DEF
# 95085  15076784         F   RN  RENV S/SIT FINAL DEF
# 95086   9115560         F   RN  RENV S/SIT FINAL DEF
#
# [2420 rows x 10 columns]
